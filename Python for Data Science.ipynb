# %% [markdown]
# **1. Hello World**

# %%
"Hello World!"
# Out:
# 'Hello World!'

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
#printing my name
print("Shreya")
# Out:
# Shreya

# %% [markdown]
# **2. Data Types**

# %%
type(1)
# Out:
# int

# %%
type(2.6)
# Out:
# float

# %%
1+2
# Out:
# 3

# %%
4-1
# Out:
# 3

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
type('S')
# Out:
# str

# %%
type("shreya")
# Out:
# str

# %%
print("Hello world".upper())
print("Hello world".lower())
print("Hello world".title())
# Out:
# HELLO WORLD
# hello world
# Hello World

# %%
"Hello world".count('l')
# Out:
# 3

# %%
"Hello world".replace('o','u')
# Out:
# 'Hellu wurld'

# %% [markdown]
# **3. Variables**
